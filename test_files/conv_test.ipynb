# %%
import torch

# %%
import torch.nn as nn

# %%
input = torch.Tensor(1, 1, 28, 28)
print(input)
# Out:
# tensor([[[[7.1554e+22, 7.2697e+31, 1.8730e+31, 2.0196e-19, 1.9432e-19,
#            2.0284e-19, 2.6793e+20, 4.7420e+30, 6.6532e-33, 1.3563e-19,
#            1.7750e+28, 7.1377e+31, 5.3740e+19, 3.0478e+32, 1.2118e+25,
#            1.8502e+28, 8.5305e+02, 6.1101e-04, 4.3988e+21, 7.5631e+28,
#            5.2839e-11, 3.0951e+35, 1.3292e-14, 5.9619e+31, 4.2964e+24,
#            1.8525e+28, 7.5018e+28, 2.9584e+21],
#           [7.1856e+22, 1.3556e-19, 7.1839e+28, 1.2799e+22, 4.3066e+21,
#            7.8899e+34, 4.6029e+30, 3.0301e+35, 7.2251e+28, 6.6532e-33,
#            4.0643e+24, 1.5137e-13, 7.1377e+31, 5.3740e+19, 7.0814e+31,
#            6.9785e+22, 1.5110e-13, 4.6247e+19, 1.0894e+27, 6.4678e+19,
#            6.7340e+22, 1.1866e+27, 1.5113e-13, 1.4822e+11, 4.8617e+30,
#            1.8499e+20, 1.7753e+28, 2.0535e-19],
#           [7.5563e+31, 1.8014e+25, 5.0834e+31, 1.2119e+25, 4.3053e+21,
#            4.9657e+28, 1.0886e+27, 7.3697e+28, 7.3839e+22, 4.7352e+22,
# ...

# %%
conv1 = nn.Conv2d(1, 5, 5)

# %%
pool = nn.MaxPool2d(2)

# %%
out = conv1(input)

# %%
out2 = pool(out)

# %%
out.size()
# Out:
# torch.Size([1, 5, 24, 24])

# %%
out2.size()
# Out:
# torch.Size([1, 5, 12, 12])
